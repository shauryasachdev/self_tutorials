# %%
print("My Second Python Tutorial")
# Out:
# My Second Python Tutorial

# %%
print("some changes to the second")
# Out:
# some changes to the second

# %%
print("some final changes to 2")
# Out:
# some final changes to 2
